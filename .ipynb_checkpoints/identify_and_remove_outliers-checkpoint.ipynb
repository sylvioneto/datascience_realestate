# %% [markdown]
# # Identifying and removing outliers

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('figure', figsize = (20,10))

# %%
df_rent_data = pd.read_csv("data/aluguel.csv", sep=";")
df_rent_data.head()
# Out:
#                       Type         Location  Bedrooms  Parking  Suites  Area  \
# 0                Quitinete       Copacabana         1        0       0    40
# 1                     Casa  Jardim Botânico         2        0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca         0        4       0   150
# 3              Apartamento           Centro         1        0       0    15
# 4              Apartamento     Higienópolis         1        0       0    48
#
#      Rent  Condo fee  City fee  Total Gross  Rent/Sqm  Total Gross/Sqm  \
# 0  1700.0      500.0      60.0       2260.0     42.50            56.50
# 1  7000.0        0.0       0.0       7000.0     70.00            70.00
# 2  5200.0     4020.0    1111.0      10331.0     34.67            68.87
# 3   800.0      390.0      20.0       1210.0     53.33            80.67
# 4   800.0      230.0       0.0       1030.0     16.67            21.46
#
#   House/Apart
# 0      Others
# 1       House
# 2      Others
# 3   Apartment
# 4   Apartment

# %%
# identify the edges
rent = df_rent_data['Rent']
q1 = rent.quantile(.25)
q3 = rent.quantile(.75)
iiq = q3 - q1
bottom_limit = q1 - 1.5 * iiq
top_limit = q3 + 1.5 * iiq
print("Bottom limit {}, Top limit {}".format(bottom_limit, top_limit))
# Out:
# Bottom limit -6000.0, Top limit 14000.0

# %%
# removing outliers
selection =  (rent >= bottom_limit) & (rent <= top_limit)
df_rent_selected = df_rent_data[selection]

# %%
# present with boxsplot
df_rent_selected.boxplot(['Rent'])

# %%
# present with histogram
df_rent_selected.hist(['Rent'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A4A9AA15F8>]],
#       dtype=object)

# %% [markdown]
# # Identifying and removing outliers by group

# %%
# group the rent price by type
df_rent_selected_group = df_rent_data.groupby('Type')['Rent']
df_rent_selected_group.groups
# Out:
# {'Apartamento': Int64Index([    3,     4,     5,     6,    10,    11,    12,    13,    15,
#                 19,
#              ...
#              32943, 32944, 32947, 32949, 32950, 32951, 32953, 32956, 32957,
#              32958],
#             dtype='int64', length=19532),
#  'Box/Garagem': Int64Index([  207,   373,   579,   885,  1014,  1636,  1664,  1850,  1945,
#               2502,  3084,  3471,  3587,  3605,  3783,  3860,  3960,  4000,
#               4273,  5885,  6123,  6775,  7169,  7446,  7932,  9239,  9309,
#               9327,  9726, 10304, 10467, 11488, 12056, 12118, 12229, 12763,
#              12783, 13251, 13887, 13970, 15116, 15635, 16270, 16518, 17413,
#              17631, 18089, 18777, 19106, 19585, 20039, 20296, 20805, 21262,
#              21346, 21689, 22339, 22351, 22559, 23957, 24470, 24801, 25072,
#              25206, 25385, 25636, 26346, 26758, 26831, 27673, 28675, 28691,
#              28692, 28931, 29441, 30071, 30261, 30863, 31175, 31646, 32625,
#              32954],
#             dtype='int64'),
#  'Casa': Int64Index([    1,    31,    74,    82,   138,   142,   216,   236,   269,
#                357,
#              ...
#              32613, 32644, 32652, 32732, 32739, 32778, 32859, 32893, 32911,
#              32931],
#             dtype='int64', length=967),
#  'Casa Comercial': Int64Index([   83,   204,   287,   490,   668,   725,   829,   850,   930,
#                964,
#              ...
#              31088, 31322, 31426, 31563, 32015, 32076, 32079, 32263, 32461,
#              32752],
#             dtype='int64', length=265),
#  'Casa de Condomínio': Int64Index([    7,     8,    18,    22,    59,    85,   248,   253,   272,
#                306,
#              ...
#              32792, 32796, 32807, 32853, 32867, 32869, 32898, 32908, 32924,
#              32952],
#             dtype='int64', length=996),
#  'Casa de Vila': Int64Index([  117,   312,   324,   459,   504,  1052,  1239,  1271,  1377,
#               1515,
#              ...
#              32041, 32048, 32137, 32245, 32282, 32302, 32620, 32686, 32804,
#              32865],
#             dtype='int64', length=249),
#  'Chácara': Int64Index([2157], dtype='int64'),
#  'Conjunto Comercial/Sala': Int64Index([    2,     9,    26,    35,    38,    42,    45,    46,    52,
#                 53,
#              ...
#              32913, 32917, 32923, 32926, 32937, 32939, 32942, 32946, 32948,
#              32959],
#             dtype='int64', length=6815),
#  'Flat': Int64Index([   17,    25,   210,   211,   288,   403,   670,   786,   843,
#               1088,
#              ...
#              32368, 32388, 32412, 32460, 32504, 32541, 32557, 32624, 32783,
#              32836],
#             dtype='int64', length=476),
#  'Galpão/Depósito/Armazém': Int64Index([   80,    84,   120,   149,   318,   326,   350,   353,   429,
#                494,
#              ...
#              32475, 32494, 32578, 32635, 32705, 32750, 32814, 32837, 32897,
#              32899],
#             dtype='int64', length=623),
#  'Hotel': Int64Index([9687, 26977], dtype='int64'),
#  'Indústria': Int64Index([23614], dtype='int64'),
#  'Loft': Int64Index([  347,   848,  1305,  3012,  3267,  4314,  4840,  4883,  5252,
#               6043,  7164,  7249,  7662,  8102,  9069,  9542,  9970, 10063,
#              10730, 11555, 11574, 11715, 12566, 12574, 12785, 14449, 17098,
#              17228, 17402, 17543, 17888, 18552, 19780, 19878, 21186, 21205,
#              21648, 21935, 22394, 23346, 23584, 25694, 27111, 27117, 27374,
#              27522, 29501, 29756, 30472, 30510, 32491],
#             dtype='int64'),
#  'Loja Shopping/ Ct Comercial': Int64Index([  589,   594,   606,   618,   680,   883,   892,   937,   951,
#               1070,
#              ...
#              31044, 31158, 31346, 31357, 31478, 31853, 32065, 32226, 32293,
#              32927],
#             dtype='int64', length=247),
#  'Loja/Salão': Int64Index([   29,    58,   103,   172,   176,   214,   250,   251,   260,
#                274,
#              ...
#              32747, 32768, 32798, 32801, 32802, 32845, 32846, 32914, 32928,
#              32929],
#             dtype='int64', length=1426),
#  'Loteamento/Condomínio': Int64Index([3354, 14707, 25294, 25797, 25880], dtype='int64'),
#  'Pousada/Chalé': Int64Index([4721], dtype='int64'),
#  'Prédio Inteiro': Int64Index([   16,   305,   344,   513,   753,   974,  1402,  1459,  1678,
#               1821,
#              ...
#              31586, 31595, 31720, 31721, 31734, 32016, 32284, 32400, 32528,
#              32833],
#             dtype='int64', length=301),
#  'Quitinete': Int64Index([    0,    14,    39,   100,   110,   123,   143,   183,   220,
#                262,
#              ...
#              32324, 32359, 32398, 32718, 32755, 32763, 32818, 32844, 32945,
#              32955],
#             dtype='int64', length=836),
#  'Studio': Int64Index([6983, 8303, 15071, 28178], dtype='int64'),
#  'Sítio': Int64Index([4379, 4425, 10868, 18786, 20806, 24642, 26873, 27061, 27180,
#              30120],
#             dtype='int64'),
#  'Terreno Padrão': Int64Index([  159,   551,  1365,  1505,  1724,  2011,  2759,  2937,  3421,
#               3931,  4009,  4364,  4370,  4389,  4837,  5669,  6201,  6693,
#               7110,  7206,  7955,  8029,  8459,  8477,  9725, 10243, 10419,
#              10494, 11644, 11802, 11935, 12005, 13019, 13236, 13387, 13796,
#              14213, 14299, 14471, 15271, 15495, 15795, 16043, 17050, 17276,
#              17389, 18349, 19044, 19757, 20082, 20399, 20733, 20810, 20857,
#              20875, 21154, 22691, 23342, 23897, 24235, 24259, 24382, 25407,
#              25845, 27352, 28257, 29433, 29629, 30016, 30916],
#             dtype='int64')}

# %%
q1 = df_rent_selected_group.quantile(.25)
q3 = df_rent_selected_group.quantile(.75)
iiq = q3 - q1
bottom_limit = q1 - 1.5 * iiq
top_limit = q3 + 1.5 * iiq

# %%
# remove outlines by rent type
df_data_new = pd.DataFrame()

# for each type, select the records whithin the outlines
for rent_type in df_rent_selected_group.groups.keys():
    is_type = df_rent_data['Type'] == rent_type
    df_type_selected = df_rent_data[is_type]
    
    is_within_limits = (df_type_selected['Rent'] >= bottom_limit[rent_type]) & (df_type_selected['Rent'] <= top_limit[rent_type])
    df_within_limits = df_type_selected[is_within_limits]
    
    df_data_new = pd.concat([df_data_new, df_within_limits])

df_data_new.shape
# Out:
# (29896, 13)

# %%
df_rent_data['Rent']
# Out:
# 0         1700.0
# 1         7000.0
# 2         5200.0
# 3          800.0
# 4          800.0
# 5         1200.0
# 6         1300.0
# 7        22000.0
# 8         1000.0
# 9        35000.0
# 10        1200.0
# 11        1500.0
# 12        1500.0
# 13        2000.0
# 14        1800.0
# 15       13000.0
# 16       28000.0
# 17        3800.0
# 18        2000.0
# 19         950.0
# 20        1700.0
# 21        1900.0
# 22        7500.0
# 23        1000.0
# 24        2000.0
# 25        4500.0
# 26        1100.0
# 27        7000.0
# 28         750.0
# 29        1300.0
#           ...
# 32930      500.0
# 32931     5000.0
# 32932     1500.0
# 32933     2100.0
# 32934     2200.0
# 32935     4300.0
# 32936     4100.0
# 32937    10000.0
# 32938     1950.0
# 32939     1100.0
# 32940     2250.0
# 32941     2300.0
# 32942     2000.0
# 32943     5500.0
# 32944     1550.0
# 32945     1500.0
# 32946     4000.0
# 32947     3000.0
# 32948      600.0
# 32949    15000.0
# 32950     1000.0
# 32951     1000.0
# 32952    15000.0
# 32953      900.0
# 32954    14000.0
# 32955      800.0
# 32956     1800.0
# 32957     1400.0
# 32958     3000.0
# 32959     6500.0
# Name: Rent, Length: 32960, dtype: float64
